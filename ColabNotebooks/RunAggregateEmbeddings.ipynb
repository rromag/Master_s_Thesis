# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import sys
import torch

# %%
sys.path.append("/content/drive/MyDrive/Masters_Thesis")

# %%
torch.cuda.is_available()
# Out:
# True

# %%
from NLP_Analysis import AggregateEmbeddings

# %%
AggregateEmbeddings(Review_Type="Audience")
# Out:
# PROJECT_ROOT: /content/drive/MyDrive/Masters_Thesis
# Looking in folder: /content/drive/MyDrive/Masters_Thesis/NLP Data/Audience Embeddings
# 100%|██████████| 9116/9116 [00:03<00:00, 2420.23it/s]
# Processed 1665270 reviews across 9116 movies.
#                                    id  \
# 0                            10000_bc
# 1                    1000218-accident
# 2                  10002516-lost_city
# 3     10002635-bridge_of_san_luis_rey
# 4                   10003276-criminal
# ...                               ...
# 9111                              zoo
# 9112                        zookeeper
# 9113                        zoolander
# 9114                      zoolander_2
# 9115                        zoom_2006
#
#                                              embeddings
# 0     [-0.03942528087599016, 0.0032700514138010463, ...
# 1     [-0.02399500713051696, -0.0307859453792584, -0...
# 2     [-0.03502643047207676, 0.010035118767642416, -...
# 3     [-0.01785140314605087, -0.025767731200903653, ...
# 4     [-0.052772209397953705, -0.027951262337912338,...
# ...                                                 ...
# 9111  [-0.017847034802194683, 0.010725462333241013, ...
# 9112  [-0.05081028050708119, -0.010040441195946187, ...
# 9113  [-0.056800212225178254, -0.015408879466354847,...
# 9114  [-0.04371405524004393, -0.023118812325980932, ...
# 9115  [-0.04003898069623392, -0.006135311179023119, ...
#
# [9116 rows x 2 columns]

# %%
AggregateEmbeddings(Review_Type="Critic")
# Out:
# PROJECT_ROOT: /content/drive/MyDrive/Masters_Thesis
# Looking in folder: /content/drive/MyDrive/Masters_Thesis/NLP Data/Critic Embeddings
# 100%|██████████| 9116/9116 [00:02<00:00, 3801.65it/s]
# Processed 936349 reviews across 9116 movies.
#                                    id  \
# 0                            10000_bc
# 1                    1000218-accident
# 2                  10002516-lost_city
# 3     10002635-bridge_of_san_luis_rey
# 4                   10003276-criminal
# ...                               ...
# 9111                              zoo
# 9112                        zookeeper
# 9113                        zoolander
# 9114                      zoolander_2
# 9115                        zoom_2006
#
#                                              embeddings
# 0     [-0.029380889835797338, 0.013254167158585324, ...
# 1     [-0.00709496159106493, -0.020565725524128147, ...
# 2     [-0.006343667547931729, -0.007982953772821192,...
# 3     [-0.014915107875519121, -0.009466946428195419,...
# 4     [-0.036120476975689784, -0.0379468278341188, -...
# ...                                                 ...
# 9111  [-0.016304729080729885, -0.0005986704438162798...
# 9112  [-0.025382070247707524, -0.025929988127509275,...
# 9113  [-0.031109530706089572, -0.022941161730961862,...
# 9114  [-0.03752209954508679, -0.022605803511799017, ...
# 9115  [-0.024536288960542364, -0.009068323607446955,...
#
# [9116 rows x 2 columns]
