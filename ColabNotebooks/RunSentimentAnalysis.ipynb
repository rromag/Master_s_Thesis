# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import sys
import torch

# %%
sys.path.append("/content/drive/MyDrive/Masters_Thesis")

# %%
torch.cuda.is_available()
# Out:
# True

# %%
import NLP_Analysis
from NLP_Analysis import NLPAnalysis
from NLP_Analysis import MovieReviewSentimentAnalyser

# %%
NLPAnalysis(Review_Type = "Audience", Analysis_Type = "sentiment", chunk_size = 2048)
# Out:
# PROJECT_ROOT: /content/drive/MyDrive/Masters_Thesis
# Looking in folder: /content/drive/MyDrive/Masters_Thesis/Rotten Tomatoes Reviews/Audience Reviews Preprocessed for NLP
# Glob pattern: rt_audience_reviews_preprocessed_*.json
# [→] Processing file 0/24: rt_audience_reviews_preprocessed_0.json, doing Sentiment analysis on 8 threads…
# Processing Chunk 1/33
# Runtime Chunk 1: 6.67 seconds
# Processing Chunk 2/33
# Runtime Chunk 2: 5.62 seconds
# Processing Chunk 3/33
# Runtime Chunk 3: 6.02 seconds
# Processing Chunk 4/33
# Runtime Chunk 4: 5.96 seconds
# Processing Chunk 5/33
# Runtime Chunk 5: 6.28 seconds
# Processing Chunk 6/33
# Runtime Chunk 6: 6.21 seconds
# Processing Chunk 7/33
# Runtime Chunk 7: 6.28 seconds
# Processing Chunk 8/33
# Runtime Chunk 8: 6.31 seconds
# Processing Chunk 9/33
# Runtime Chunk 9: 6.21 seconds
# Processing Chunk 10/33
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# ...

# %%
NLPAnalysis(Review_Type = "Critic", Analysis_Type = "sentiment", chunk_size = 2048)
# Out:
# PROJECT_ROOT: /content/drive/MyDrive/Masters_Thesis
# Looking in folder: /content/drive/MyDrive/Masters_Thesis/Rotten Tomatoes Reviews/Critic Reviews Preprocessed for NLP
# Glob pattern: rt_critic_reviews_preprocessed_*.json
# [→] Processing file 0/19: rt_critic_reviews_preprocessed_0.json, doing Sentiment analysis on 8 threads…
# Processing Chunk 1/23
# Runtime Chunk 1: 1.96 seconds
# Processing Chunk 2/23
# Runtime Chunk 2: 1.95 seconds
# Processing Chunk 3/23
# Runtime Chunk 3: 1.94 seconds
# Processing Chunk 4/23
# Runtime Chunk 4: 1.93 seconds
# Processing Chunk 5/23
# Runtime Chunk 5: 1.94 seconds
# Processing Chunk 6/23
# Runtime Chunk 6: 2.00 seconds
# Processing Chunk 7/23
# Runtime Chunk 7: 2.01 seconds
# Processing Chunk 8/23
# Runtime Chunk 8: 2.02 seconds
# Processing Chunk 9/23
# Runtime Chunk 9: 1.94 seconds
# Processing Chunk 10/23
# Runtime Chunk 10: 1.96 seconds
# Processing Chunk 11/23
# Runtime Chunk 11: 1.98 seconds
# Processing Chunk 12/23
# ...
